# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
dataset = pd.read_csv(r"C:\Users\SOHINI\Downloads\ASIANPAINT.csv",index_col="Date",parse_dates=True)

# %%
dataset.head()
# Out:
#                 Symbol Series  Prev Close   Open   High    Low   Last   Close  \
# Date
# 2000-01-03  ASIANPAINT     EQ      361.20  370.0  390.0  370.0  385.0  381.65
# 2000-01-04  ASIANPAINT     EQ      381.65  380.0  392.0  375.0  390.0  385.55
# 2000-01-05  ASIANPAINT     EQ      385.55  371.5  390.0  371.5  383.0  383.00
# 2000-01-06  ASIANPAINT     EQ      383.00  384.9  384.9  374.5  375.1  377.50
# 2000-01-07  ASIANPAINT     EQ      377.50  376.0  390.0  370.0  389.0  385.70
#
#               VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2000-01-03  380.54    3318  1.262617e+11     NaN                 NaN
# 2000-01-04  383.50    4818  1.847699e+11     NaN                 NaN
# 2000-01-05  379.81    2628  9.981384e+10     NaN                 NaN
# 2000-01-06  379.88    3354  1.274114e+11     NaN                 NaN
# 2000-01-07  383.38    9589  3.676275e+11     NaN                 NaN
#
#             %Deliverble
# Date
# 2000-01-03          NaN
# 2000-01-04          NaN
# 2000-01-05          NaN
# 2000-01-06          NaN
# 2000-01-07          NaN

# %%
dataset.isna().any()  #check if there is any non applicable values...here everything is false(in non app) so every value is applicable
# Out:
# Symbol                False
# Series                False
# Prev Close            False
# Open                  False
# High                  False
# Low                   False
# Last                  False
# Close                 False
# VWAP                  False
# Volume                False
# Turnover              False
# Trades                 True
# Deliverable Volume     True
# %Deliverble            True
# dtype: bool

# %%
dataset=dataset.drop(['Turnover','Symbol','Prev Close','Series','Deliverable Volume','%Deliverble'],axis=1)
dataset.head()
# Out:
#              Open   High    Low   Last   Close    VWAP  Volume  Trades
# Date
# 2000-01-03  370.0  390.0  370.0  385.0  381.65  380.54    3318     NaN
# 2000-01-04  380.0  392.0  375.0  390.0  385.55  383.50    4818     NaN
# 2000-01-05  371.5  390.0  371.5  383.0  383.00  379.81    2628     NaN
# 2000-01-06  384.9  384.9  374.5  375.1  377.50  379.88    3354     NaN
# 2000-01-07  376.0  390.0  370.0  389.0  385.70  383.38    9589     NaN

# %%
dataset=dataset.drop(['VWAP','Trades'],axis=1)
dataset.head()
# Out:
#              Open   High    Low   Last   Close  Volume
# Date
# 2000-01-03  370.0  390.0  370.0  385.0  381.65    3318
# 2000-01-04  380.0  392.0  375.0  390.0  385.55    4818
# 2000-01-05  371.5  390.0  371.5  383.0  383.00    2628
# 2000-01-06  384.9  384.9  374.5  375.1  377.50    3354
# 2000-01-07  376.0  390.0  370.0  389.0  385.70    9589

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5306 entries, 2000-01-03 to 2021-04-30
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5306 non-null   float64
#  1   High    5306 non-null   float64
#  2   Low     5306 non-null   float64
#  3   Last    5306 non-null   float64
#  4   Close   5306 non-null   float64
#  5   Volume  5306 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 290.2 KB

# %%
dataset["Open"].plot(figsize=(16,6))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
dataset["Volume"] = dataset["Volume"].str.replace(',','').astype(float)  #convert volume as float64 to make every column of same type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 dataset["Volume"] = dataset["Volume"].str.replace(',','').astype(float)  #convert volume as float64 to make every column of same type
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\strings\accessor.py:181, in StringMethods.__init__(self, data)
#     178 def __init__(self, data) -> None:
#     179     from pandas.core.arrays.string_ import StringDtype
# --> 181     self._inferred_dtype = self._validate(data)
#     182     self._is_categorical = is_categorical_dtype(data.dtype)
#     183     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\strings\accessor.py:235, in StringMethods._validate(data)
#     232 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     234 if inferred_dtype not in allowed_types:
# --> 235     raise AttributeError("Can only use .str accessor with string values!")
#     236 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20 entries, 2017-01-03 to 2017-01-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    20 non-null     float64
#  1   High    20 non-null     float64
#  2   Low     20 non-null     float64
#  3   Close   20 non-null     float64
#  4   Volume  20 non-null     float64
# dtypes: float64(5)
# memory usage: 960.0 bytes

# %%
dataset.rolling(3).mean().head(20)
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-01-03         NaN         NaN         NaN         NaN           NaN
# 2017-01-04         NaN         NaN         NaN         NaN           NaN
# 2017-01-05  784.416667  791.816667  781.326667  789.020000  1.355167e+06
# 2017-01-06  789.900000  797.906667  786.793333  795.690000  1.349467e+06
# 2017-01-09  795.913333  804.116667  793.350000  802.273333  1.415933e+06
# 2017-01-10  803.173333  809.000000  799.513333  805.863333  1.363133e+06
# 2017-01-11  806.420000  809.083333  802.570000  806.450000  1.171700e+06
# 2017-01-12  806.666667  808.223333  801.350000  806.353333  1.198600e+06
# 2017-01-13  806.540000  808.920000  802.410000  807.383333  1.172733e+06
# 2017-01-17  807.233333  808.583333  802.076667  806.283333  1.271467e+06
# 2017-01-18  806.790000  808.190000  802.683333  806.186667  1.251900e+06
# 2017-01-19  806.003333  807.610000  801.053333  804.283333  1.191933e+06
# 2017-01-20  805.946667  807.533333  801.493333  804.420000  1.294567e+06
# 2017-01-23  806.426667  812.420000  802.410000  808.833333  1.517633e+06
# 2017-01-24  812.153333  817.893333  807.750000  816.066667  1.702533e+06
# 2017-01-25  819.723333  827.513333  815.540000  826.283333  1.644033e+06
# 2017-01-26  829.910000  833.223333  823.296667  830.563333  1.980800e+06
# 2017-01-27  834.046667  838.573333  824.170000  830.376667  2.478067e+06
# 2017-01-30  829.060000  831.930000  815.750000  819.260000  3.062100e+06
# 2017-01-31  815.410000  819.680000  803.586667  807.473333  2.791000e+06

# %%
dataset["Open"].plot(figsize=(16,6))
dataset.rolling(3).mean()['Close'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
dataset["Open"].plot(figsize=(16,6))
dataset["Close"].rolling(3).mean().plot(figsize=(10,6))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
dataset["Close : 3 day Rolling Mean"] = dataset["Close"].rolling(3).mean()
dataset[["Close","Close : 3 day Rolling Mean"]].plot(figsize=(16,6))
# Out:
# <AxesSubplot: xlabel='Date'>
